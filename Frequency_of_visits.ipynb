# %%
import pandas as pd
import matplotlib.pyplot as plt

# 读取数据集
data = pd.read_csv('data-0.csv')  # 替换成你的数据集文件名

# 计算平均月就诊天数、月就诊医院数和月就诊次数
average_days = data['月就诊天数_AVG'].mean()
average_hospitals = data['月就诊医院数_AVG'].mean()
average_visits = data['月就诊次数_AVG'].mean()

# 可视化
labels = ['Average Monthly Visited Days', 'Average Monthly Visited Hospitals', 'Average Monthly Visits']
values = [average_days, average_hospitals, average_visits]

plt.figure(figsize=(8, 4))  # 增加图像的宽度
plt.bar(labels, values)
plt.xlabel('Metrics')
plt.ylabel('Average Values')
plt.title('Visitation Frequency Analysis')
plt.tight_layout()  # 调整图像布局
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 读取数据集
data = pd.read_csv('data-0.csv')  # 替换成你的数据集文件名

# 按个人编码分组并计算平均值
grouped_data = data.groupby('个人编码').mean()

# 获取个人编码和对应的平均值
individuals = grouped_data.index
average_days = grouped_data['月就诊天数_AVG']
average_hospitals = grouped_data['月就诊医院数_AVG']
average_visits = grouped_data['月就诊次数_AVG']

# 可视化
plt.figure(figsize=(10, 6))

plt.subplot(3, 1, 1)
plt.bar(individuals, average_days)
plt.xlabel('个人编码')
plt.ylabel('平均月就诊天数')
plt.title('个人就诊频率分析')

plt.subplot(3, 1, 2)
plt.bar(individuals, average_hospitals)
plt.xlabel('个人编码')
plt.ylabel('平均月就诊医院数')

plt.subplot(3, 1, 3)
plt.bar(individuals, average_visits)
plt.xlabel('个人编码')
plt.ylabel('平均月就诊次数')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3491468/1525633318.py:35: UserWarning: Glyph 20010 (\N{CJK UNIFIED IDEOGRAPH-4E2A}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3491468/1525633318.py:35: UserWarning: Glyph 20154 (\N{CJK UNIFIED IDEOGRAPH-4EBA}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3491468/1525633318.py:35: UserWarning: Glyph 32534 (\N{CJK UNIFIED IDEOGRAPH-7F16}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3491468/1525633318.py:35: UserWarning: Glyph 30721 (\N{CJK UNIFIED IDEOGRAPH-7801}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3491468/1525633318.py:35: UserWarning: Glyph 24179 (\N{CJK UNIFIED IDEOGRAPH-5E73}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3491468/1525633318.py:35: UserWarning: Glyph 22343 (\N{CJK UNIFIED IDEOGRAPH-5747}) missing from current font.
#   plt.tight_layout()
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 读取数据集
data = pd.read_csv('data-0.csv')

# 按个人编码分组并计算平均值
grouped_data = data.groupby('个人编码').mean()

# 打印输出表格中的前5行
# print(grouped_data.head())

# 获取个人编码和对应的平均值
individuals = grouped_data.index
average_days = grouped_data['月就诊天数_AVG']
average_hospitals = grouped_data['月就诊医院数_AVG']
average_visits = grouped_data['月就诊次数_AVG']

# 可视化
plt.figure(figsize=(10, 6))

plt.bar(individuals, average_days, label='Average Monthly Visit Days')
plt.bar(individuals, average_hospitals, bottom=average_days, label='Average Monthly Visit Hospitals')
plt.bar(individuals, average_visits, bottom=average_days + average_hospitals, label='Average Monthly Visits')

print(grouped_data.head())
plt.xlabel('Personal Code')
plt.ylabel('Average')
plt.title('Individual Visit Frequency Analysis')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
#               一天去两家医院的天数     就诊的月数  月就诊天数_MAX  月就诊天数_AVG  月就诊医院数_MAX  \
# 个人编码
# 3.521200e+14    1.928581  5.825601   7.847673   5.863193    2.119078
# 3.521210e+14    1.516882  5.753837   7.682014   5.812451    1.939840
# 3.521260e+14    2.071429  5.750000   7.428571   5.704762    2.035714
# 3.521280e+14    1.512821  5.777778   7.076923   5.461681    1.888889
#
#               月就诊医院数_AVG   就诊次数_SUM  月就诊次数_MAX  月就诊次数_AVG    月统筹金额_MAX  ...  \
# 个人编码                                                                    ...
# 3.521200e+14    1.750534  36.955504   8.457753   6.282597  3836.430243  ...
# 3.521210e+14    1.618345  35.862492   8.147944   6.142101  4810.786648  ...
# 3.521260e+14    1.760714  34.964286   8.142857   6.184524  5369.295000  ...
# 3.521280e+14    1.594729  33.905983   7.581197   5.758832  4502.553590  ...
#
#               药品在总金额中的占比  个人支付的药品占比  检查总费用在总金额占比  个人支付检查费用占比  治疗费用在总金额占比  \
# 个人编码
# 3.521200e+14    0.857965   0.005522     0.038758    0.005209    0.077843
# ...
